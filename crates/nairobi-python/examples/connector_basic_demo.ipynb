# %% [markdown]
# # Nairobi OS - Basic MCP Connector Demo
#
# Demonstrates the core MCP tools from Nairobi Connector:
# - Starting the MCP server
# - Finding windows by title
# - Getting TOON UI maps
# - Basic interactions (click, focus, activate)

# %%
import nairobi_os

print(f"Nairobi OS version: {nairobi_os.__version__}")

# %% [markdown]
# ## Available MCP Connector Functions

# %%
ui_functions = [func for func in dir(nairobi_os.ui) if not func.startswith('_')]
for func in sorted(ui_functions):
    print(f"  - {func}")

# %% [markdown]
# ## MCP Connector Usage Pattern

# %%
# Start the MCP server (auto-starts on first use)
# nairobi_os.ui.start()
# print('✓ MCP server started successfully!')

# Find a window by title
# result = nairobi_os.ui.find_window("Terminal")
# print(f"Find result: {result}")

# Get the UI accessibility tree as TOON format
# toon_map = nairobi_os.ui.get_map()
# print("TOON Map:")
# print(toon_map)

# Interact with UI elements by node ID
# click_result = nairobi_os.ui.interact(node_id=3, action="click")
# print(f"Click result: {click_result}")

# Type text into an editable field
# type_result = nairobi_os.ui.type_text(node_id=5, text="Hello from Nairobi OS!")
# print(f"Type result: {type_result}")

# Stop the MCP server
# nairobi_os.ui.stop()
