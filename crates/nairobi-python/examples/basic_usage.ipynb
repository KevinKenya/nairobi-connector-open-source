# %% [markdown]
# # Nairobi OS Python Basic Usage Example
#
# This notebook demonstrates basic usage of the Nairobi OS Python bindings for high-performance data processing.

# %%
# Import the Nairobi OS package
import nairobi_os
import json
import pandas as pd
import numpy as np

print("Nairobi OS version:", nairobi_os.__version__)
print("Author:", nairobi_os.__author__)

# %% [markdown]
# ## Starting the Refinery Daemon
#
# Before we can process data, we need to start the Nairobi Axum Refinery daemon.

# %%
# Start the refinery daemon (this will auto-discover the binary)
nairobi_os.start_refinery()

print("Refinery daemon started successfully!")
