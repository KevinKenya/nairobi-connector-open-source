# %% [markdown]
# # Nairobi OS - SovereignFrame Pandas-Like Interface
#
# SovereignFrame high-level API:
# - Column accessor fluent API
# - DataFrame-like operations
# - SQL querying with query() method

# %%
import nairobi_os
import json

print(f"Nairobi OS version: {nairobi_os.__version__}")

# %% [markdown]
# ## High-Level SovereignFrame Interface

# %%
# Start the Refinery daemon
# nairobi_os.start_refinery()
# handle_id = nairobi_os.data.ingest("sales_data.csv")
# frame = nairobi_os.SovereignFrame(handle_id)

# %% [markdown]
# ## Column Accessor Fluent API

# %%
# Access columns via attribute (fluent API like pandas)
# mean_value = frame.revenue.mean()
# max_value = frame.revenue.max()
# std_value = frame.revenue.std_dev()
# p95_value = frame.revenue.p95()
# skew_value = frame.revenue.skewness()

# Or use dictionary syntax
# mean_value = frame['revenue'].mean()

print("ColumnAccessor methods:")
print("  - mean(), max(), min(), std_dev(), variance()")
print("  - p95(), p99(), skewness(), kurtosis()")
print("  - crunch(), calculate()")

# %% [markdown]
# ## SQL Querying with SovereignFrame

# %%
# SQL-like querying
# filtered_frame = frame.query("SELECT * FROM data WHERE revenue > 1000")
# top_customers = frame.query("SELECT * FROM data ORDER BY revenue DESC LIMIT 10")

# Correlation matrix
# corr_matrix = frame.correlate("revenue,ad_spend,leads")
